# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import gkey

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0   Mar Del Plata      AR  2021-12-21 05:20:52 -38.0023  -57.5575
# 1        1        Acapulco      MX  2021-12-21 05:23:30  16.8634  -99.8901
# 2        2  Cabo San Lucas      MX  2021-12-21 05:21:32  22.8909 -109.9124
# 3        3          Broome      US  2021-12-21 05:23:31  42.2506  -75.8330
# 4        4            Chuy      UY  2021-12-21 05:23:31 -33.6971  -53.4616
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     67.08        87         100        3.00
# 1     78.62        83          20        3.44
# 2     69.51        66          91        1.99
# 3     30.90        73           1        1.99
# 4     64.90        91           0        6.22

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=gkey)

# %%
# # 1. Assign the locations to an array of latitude and longitude pairs.
# locations = [latitude, longitude]
# # 2. Assign the weights variable to some values.
# temperatures = # an array of length equal to the locations array length
# # 3. Assign the figure variable to the gmaps.figure() attribute.
# fig = gmaps.figure()
# # 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)

# # 5. Add the heatmap layer.
# fig.add_layer(heatmap_layer)
# # 6. Call the figure to plot the data.
# fig
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
# heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Google heatmaps do not plot negative numbers. If you have a maximum temperature that is less than 0 °F, then you will get an InvalidWeightException error for this line of code:

# heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# To remove the negative temperatures we can use a for loop to iterate through the max_temp and add the temperatures that are greater than 0 °F to a new list.

# Add a new cell above our previous code block, and then add the following code in the cell and run the cell.

# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
# Add the heatmap layer.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
#
# Replace temps with our code for the list comprehension so our heat_layer code 
# looks like the following:

heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
fig.add_layer(heat_layer)
#
#
# If we scroll and zoom in on North America, we can see that the circles for the temperatures need to be modified so that they are larger and show temperature gradient differences.
# If you review the gmaps documentation, you may notice there is a dissipation option for creating heatmaps that can be added to the gmaps.heat_layer() attribute.

# The options for this are:

# The default option for the dissipation is "True," so we need to set our "dissipation" to "False."
# We can add max_intensity to make each measurement have a better gradient variance.
# We can add point_radius to make each measurement radius larger.
# heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)
#
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a Percent Humidity Heatmap
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds= city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds,dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a Wind Speed Heatmap
# Now we can create the final heatmap. Copy the code that created
# the previous heatmap and edit your code with the line wind = city_data_df["Wind Speed"] so that the wind speed replaces the percent cloudiness, 
# and set the variable weights=wind, and run your cell.
#
locations = city_data_df[["Lat", "Lng"]]
wind= city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind,dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
#
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
preferred_cities_df.count()
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90
# City_ID       203
# City          203
# Country       203
# Date          203
# Lat           203
# Lng           203
# Max Temp      203
# Humidity      203
# Cloudiness    203
# Wind Speed    203
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#          City Country  Max Temp      Lat       Lng Hotel Name
# 1    Acapulco      MX     78.62  16.8634  -99.8901
# 6       Vaini      TO     82.56 -21.2000 -175.2000
# 11     Mocuba      MZ     74.84 -16.8392   36.9856
# 14      Ilula      TZ     72.14  -7.6766   36.0366
# 17       Hilo      US     71.28  19.7297 -155.0900
# 22    Rikitea      PF     77.09 -23.1203 -134.9692
# 25  Busselton      AU     83.23 -33.6500  115.3333
# 31  Sinnamary      GF     77.27   5.3833  -52.9500
# 33   Hermanus      ZA     74.89 -34.4187   19.2345
# 38     Alugan      PH     82.74  12.2188  125.4808

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
#     hotels
    # Grab the first hotel from the results and store the name.
#     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDTKZqGMTvGWb8RfafV042_V6tZ2KMvxTJDpkrrxwmv8hWa7xoJaQXguLZ3kWIaAjQvVLG9Erv8MJ-GrLDTydU-96U6aV2Btto1Gdu6tRml5PgA_kc9sXOCpwuTLuY8uXXjLOleAU_T_M8FMoNb3zTXCfd2qm_Knsqsez9EFw3Q_GOHKo3mMVQQ-yfi47PklGGDCz9HCwAoC7HebiJHgzKUasIX0VSeWt8qYw3y-e_QJUjEDOkiRc-KZcRXy8G7kwnjaRQar2GiWljNTqGEHIVwld7fa7dQsZsZlXCi_d_U3W-74-F9PW91_sM0c-7W1-XRh_GiW3EeBXjMH1sP-5-zGyryDO7rzxqigoFcosJ3otOckyq5VQyhCOBJOzBeO_2ZDCRmdH91chMvewak2reuXgKzleHQ8e_GyHIc6LIJOOB2q4gdNwGOGGe2YeOzji4_uzFYOSm_toviR8vhfEQKmkI3C53IcfzxiJWkwJvK162D67AzRHBwb0r8IchKAawnLYzp_XKVHmv7uwI8PmmKp0MTbdLaFPHk1gtYG6CrdCNMOFfwLFUWgiQ5HKCFGSTJf9dJL8ZAqrWgt9tqlJp0xeSJcvcv7G8FJ111OlFHLGDRlpXJZ-48tI0dn-LOULAAE6jlyi-CMFz4tqWEExUUxjGhwX3t6-2_50K7sJfvLVM69VdcaDMyRjn4ZtxLiQSkHx4j_U2xeiNbJd4xeywnSgG6lAODyE3hJkGuPfyf',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.123074000000001, 'lng': 105.3075305},
#     'viewport': {'northeast': {'lat': -5.121725019708498,
#       'lng': 105.3088794802915},
#      'southwest': {'lat': -5.124422980291503, 'lng': 105.3061815197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'OYO 3177 Wisma Lintang',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 427,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115342367755621348349">OYO 3177 Wisma Lintang</a>'],
#      'photo_reference': 'Aap_uECmsR6-EckxQyEcnQXAWoX7KgJ2FN7gGTi5wXv3wSzZnbHLqUeunC5y8JkJWTqrYhanKNT8tFhwfrTBRvyt7tHzGXX97sEVuJdVYmUTFCZtOXp1ZvvEoPd_3R-kur9xVy5KL7zNDoI2SF4rD-YkzwneoF6aCu2tiJkQdrO8PIH_5w3U',
#      'width': 640}],
#    'place_id': 'ChIJ0yPsqZi5QC4RFrNE7Lmxm1o',
#    'plus_code': {'compound_code': 'V8G5+Q2 Metro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8G5+Q2'},
#    'rating': 4,
#    'reference': 'ChIJ0yPsqZi5QC4RFrNE7Lmxm1o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': 'Jalan Letjend Alamsyah Ratu Prawira Negara No.66, Metro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.112202, 'lng': 105.3059195},
#     'viewport': {'northeast': {'lat': -5.110939869708497,
#       'lng': 105.3072662302915},
#      'southwest': {'lat': -5.113637830291502, 'lng': 105.3045682697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Familie2',
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113288336557329649961">wedyadi brata</a>'],
#      'photo_reference': 'Aap_uEB01C4CYjX7Sj_NDZxniqkc_KzSjao-qO2FPiD3APKus5fkaf_OkfddXs1_xpkvOwYXlGKeV87YKs4WilhIe1sYEA9GfpLRWMX5aWfkXbwmW2fIN-A2Pz4LM-zRsLItwX2TBp5pKdAOSYb9GbMVNWJM9x5Qldypm_MZekLzkZsNiQn7',
#      'width': 1920}],
#    'place_id': 'ChIJa0d1mPC7QC4RqpHI16ej-b4',
#    'plus_code': {'compound_code': 'V8Q4+49 Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8Q4+49'},
#    'rating': 4,
#    'reference': 'ChIJa0d1mPC7QC4RqpHI16ej-b4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 587,
#    'vicinity': 'Jl. Sukarso No.3, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1143228, 'lng': 105.3150953},
#     'viewport': {'northeast': {'lat': -5.112876019708497,
#       'lng': 105.3164434802915},
#      'southwest': {'lat': -5.115573980291502, 'lng': 105.3137455197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Grand Sekuntum, Metro',
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107763225610796176137">Muhammad Iqbal</a>'],
#      'photo_reference': 'Aap_uEDSIb6QMDoRB8d00iXeRJ52bTERIjoiV7fVpvaoFcD-j9Idehij8Uj76f8cvvVawqejKpAN_DBJ3Uz1_nKgpPD4DPiZVIEs4Gc05HMtufjoaxAqEvjYAvdtmM-aHIFGlLQo3a5IqPRIefRNY0LkYYElVuEqSpptlldHH7n2_wUz8DVM',
#      'width': 6720}],
#    'place_id': 'ChIJo2Z7vAe8QC4RukPke1kYkc4',
#    'plus_code': {'compound_code': 'V8P8+72 Yosorejo, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P8+72'},
#    'rating': 4.1,
#    'reference': 'ChIJo2Z7vAe8QC4RukPke1kYkc4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 626,
#    'vicinity': 'Jalan AH Nasution No.60, Yosorejo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1249724, 'lng': 105.3070839},
#     'viewport': {'northeast': {'lat': -5.123523469708497,
#       'lng': 105.3084968302915},
#      'southwest': {'lat': -5.126221430291502, 'lng': 105.3057988697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'IDeA Indonesia Academy',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102817300012728513050">IDeA Indonesia Sekolah Perhotelan Terbaik 100% Jaminan Kerja WA 0852699979OO</a>'],
#      'photo_reference': 'Aap_uEBIIt9gx6X7JLf1OX4lPRsoOmw8FaEJmiWN79lNxhEaRK4flFIotWCx-LvSCeFDG7ddYCJRC2ZvJ8VyH4g_K913hoLY2wdCghaJJZ7LM8kNkGbfj2Fa0D5SUacIHdQI9qWDMMA3JhaBv3gG9wOql5eNggKg25YwDvQdLkG3ZAqifdvY',
#      'width': 1280}],
#    'place_id': 'ChIJ______67QC4R05Go5ObQdMI',
#    'plus_code': {'compound_code': 'V8G4+2R Metro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8G4+2R'},
#    'rating': 4.9,
#    'reference': 'ChIJ______67QC4R05Go5ObQdMI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'school', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 519,
#    'vicinity': 'Jl. AR. Prawira Negara No.99A, Metro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1238581, 'lng': 105.301595},
#     'viewport': {'northeast': {'lat': -5.122507119708498,
#       'lng': 105.3030325802915},
#      'southwest': {'lat': -5.125205080291503, 'lng': 105.3003346197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'WISMA CENTRUM Sinode GKSBS',
#    'photos': [{'height': 1872,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110528131170258018650">Anes Dwi</a>'],
#      'photo_reference': 'Aap_uECWwF1OAmD1-nWD6SV_0M4mtKi0zq4GWX_7FYCpkCkoVKLU2IvfM2CiF90F-tF45d8q6UFIL8m5l-nP6dyLNEjxtPK_oYxQAEyI7wfeBoJfQiFO78wmHbQTA78KI5O1bPH9b1hXfkw1vGohW7fhBsS3gC4MUDt_k5pPkGZlw5zkKRFj',
#      'width': 3328}],
#    'place_id': 'ChIJ9bzBIVi5QC4RdaPlsf-ixa4',
#    'plus_code': {'compound_code': 'V8G2+FJ Metro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8G2+FJ'},
#    'rating': 4.4,
#    'reference': 'ChIJ9bzBIVi5QC4RdaPlsf-ixa4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 66,
#    'vicinity': 'Jalan Yos Sudarso No.78, Metro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.117810800000001, 'lng': 105.2955983},
#     'viewport': {'northeast': {'lat': -5.116480619708498,
#       'lng': 105.2970018302915},
#      'southwest': {'lat': -5.119178580291503, 'lng': 105.2943038697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Kosan Bu Amri',
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102939605180410466966">Ahmad Husin</a>'],
#      'photo_reference': 'Aap_uECOF97ZmICUBwizSRabCrkk6Hz97sUyPF9Z23Tcnb5Fh2j6FXJ5_1EgNyPmtVVq7YntrDUkoQkUV6hGXGZki7DDv4pDX8KIoWv8PQs6-LGOxeIABseSN7xSYoJX5Uxypmeq-f8-qfxyDlykRbpV4zIAVrgQK9z7jS0fby2yjsRJGUWL',
#      'width': 2048}],
#    'place_id': 'ChIJc_fHX2-5QC4Rm29LN5WXu0g',
#    'plus_code': {'compound_code': 'V7JW+V6 Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V7JW+V6'},
#    'rating': 4.3,
#    'reference': 'ChIJc_fHX2-5QC4Rm29LN5WXu0g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 58,
#    'vicinity': 'Jalan Sulawesi No. 09, Ganjar Asri, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1130038, 'lng': 105.3067674},
#     'viewport': {'northeast': {'lat': -5.111656119708497,
#       'lng': 105.3080907802915},
#      'southwest': {'lat': -5.114354080291502, 'lng': 105.3053928197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Shelter tengah kota Grab',
#    'photos': [{'height': 721,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106202670063037539125">Atta Halilintar</a>'],
#      'photo_reference': 'Aap_uEC5xWg09UlO8xRhR-DZS0aehot6e0GT-TB19hBTGqzIc_YO-Rmlg4VbHtm4uH-5_KMDLpMvrd-ZI4Gg8KBHWgcX3Rz871J8mn5h5oG8V9ITGH2-Fd74tmktN3tx0p0mqH51UfAExGBgh1ZDTcW1CfJRnbjKh6-UlkE6kpsPoTUaHKzi',
#      'width': 1280}],
#    'place_id': 'ChIJYawJilu7QC4R0NAOuX2HMaM',
#    'rating': 4.7,
#    'reference': 'ChIJYawJilu7QC4R0NAOuX2HMaM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'V8P4+QPR, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1125235, 'lng': 105.3064777},
#     'viewport': {'northeast': {'lat': -5.111108669708497,
#       'lng': 105.3078286802915},
#      'southwest': {'lat': -5.113806630291502, 'lng': 105.3051307197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Srikandi',
#    'photos': [{'height': 2340,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100030145403286865816">Zuki Rama</a>'],
#      'photo_reference': 'Aap_uEB1BzTYlb4F9sQ-7zSRez4na5jnNGbYAAEwAmr9JVSDoO1DJDrRQ-EUh3js89PCO65C88SozJJfpTtm4NoBo3QubExbcWSL2clKRkXTErR8BPdpTsLViB-BCBPcVrYN9-Ze2M2vrVFetIZbohdYBg960DmUG4caJjLkgsTm73ArBL4M',
#      'width': 4160}],
#    'place_id': 'ChIJK68gpPC7QC4RWhTLC9WCgtg',
#    'plus_code': {'compound_code': 'V8P4+XH Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P4+XH'},
#    'rating': 4,
#    'reference': 'ChIJK68gpPC7QC4RWhTLC9WCgtg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 148,
#    'vicinity': 'Jalan Satrio Sukarso, Metro Pusat, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1123082, 'lng': 105.3065488},
#     'viewport': {'northeast': {'lat': -5.111001969708497,
#       'lng': 105.3078964802915},
#      'southwest': {'lat': -5.113699930291502, 'lng': 105.3051985197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Nuban Metro',
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102354925228127369013">Lia Hakso</a>'],
#      'photo_reference': 'Aap_uECe1RxF27kVqcvg9XMUsK-z8gUWhccAgmz2q1S7Os707Q6D-VPPQhhdDU_EqLvFIimyapakK6wK1gjzqc6TUlc5VmwOi3032jsxxJ7weqY7zmuh0wyrvHVBqKuxsoX01K5WIVkaLiqhlHBHoSHuGqn9C3RL45PxHLhyeCzz6W25jqEo',
#      'width': 3264}],
#    'place_id': 'ChIJNZGquvC7QC4RH-ctTaJn2Uw',
#    'plus_code': {'compound_code': 'V8Q4+3J Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8Q4+3J'},
#    'rating': 4.2,
#    'reference': 'ChIJNZGquvC7QC4RH-ctTaJn2Uw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 180,
#    'vicinity': 'Jl. Sukarso, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1123038, 'lng': 105.3065505},
#     'viewport': {'northeast': {'lat': -5.110999819708499,
#       'lng': 105.3078980802915},
#      'southwest': {'lat': -5.113697780291504, 'lng': 105.3052001197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Im sugges',
#    'place_id': 'ChIJ_0fCnEm7QC4RHh_fC4VAUU8',
#    'rating': 5,
#    'reference': 'ChIJ_0fCnEm7QC4RHh_fC4VAUU8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'V8Q4+3JF, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1125812, 'lng': 105.305955},
#     'viewport': {'northeast': {'lat': -5.111130019708498,
#       'lng': 105.3073066302915},
#      'southwest': {'lat': -5.113827980291503, 'lng': 105.3046086697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Masdalifah',
#    'photos': [{'height': 3648,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114598206400876082289">Harian Pakdhw</a>'],
#      'photo_reference': 'Aap_uEA-quvw1mt8Gym147KNn74k6XRmn-vdXGxGoPyihBfTb8ji6fTbD0-TkdACBP8d538XnwTwv6IO_0Ad5xebCDqDlo8_JYzXboRX3HTQnYgbqGLH2V2ZNPFLuq2zRYCJlkHZn9QrlA8PdSo2Z1BvycoAIpCN13uhVM2tp1dBCcVigw0Y',
#      'width': 2736}],
#    'place_id': 'ChIJQQiOZ5W7QC4RyGuQg4BrcqI',
#    'plus_code': {'compound_code': 'V8P4+X9 Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P4+X9'},
#    'rating': 4.2,
#    'reference': 'ChIJQQiOZ5W7QC4RyGuQg4BrcqI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': 'Jl. Sukarso No.4, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1125812, 'lng': 105.305955},
#     'viewport': {'northeast': {'lat': -5.111130019708498,
#       'lng': 105.3073066302915},
#      'southwest': {'lat': -5.113827980291503, 'lng': 105.3046086697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Nusantara Hotel',
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115778156013376599265">Musik Berbagi</a>'],
#      'photo_reference': 'Aap_uEAsMP2c_lXjbpfLuHkAkcDUgsMOi80vaMDPgaXRiL4pGjy5rPXuSa3PhxZ-nkP8NV5K79BwcNZw0_3kMlRwPX7azzP13CUQQLa_IU-1HwqoQec5SOKPX58ssgsbn7o1UoOJl4VNhrFOsjO8r3XA4IqmkVi6dZJ7ZL4eAfJ73paN774g',
#      'width': 3264}],
#    'place_id': 'ChIJG7AFueS7QC4Rfk3O7cx1kH0',
#    'plus_code': {'compound_code': 'V8P4+X9 Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P4+X9'},
#    'rating': 3.7,
#    'reference': 'ChIJG7AFueS7QC4Rfk3O7cx1kH0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 70,
#    'vicinity': 'Jl. Sukarso No.4, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.112881499999999, 'lng': 105.3085204},
#     'viewport': {'northeast': {'lat': -5.111498619708497,
#       'lng': 105.3098240802915},
#      'southwest': {'lat': -5.114196580291502, 'lng': 105.3071261197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Kos Pelita',
#    'place_id': 'ChIJd15dapW7QC4RxNG_nMUwAzc',
#    'plus_code': {'compound_code': 'V8P5+RC Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P5+RC'},
#    'rating': 5,
#    'reference': 'ChIJd15dapW7QC4RxNG_nMUwAzc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Jalan Sutrisno No.14, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1140984, 'lng': 105.304855},
#     'viewport': {'northeast': {'lat': -5.112731719708498,
#       'lng': 105.3062041802915},
#      'southwest': {'lat': -5.115429680291503, 'lng': 105.3035062197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Shelter Mega Ruko Metro Lampung',
#    'photos': [{'height': 534,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117197839500177273163">dodik hermawan</a>'],
#      'photo_reference': 'Aap_uED4B6axwYOjPPzLv9vhOzPE5q9jJzTLUQQ1ZN5sNgY0gsPM8rzwQhWQ7hAT2MhC8upV2b2HxxmIDPbtguvGYsRiYQwi3c3Sfur_cPqOF0fnYKWzblASl9SzfPEVhePYDwW9GPzUxuz-tTjz8WX-7VVBx98h4nvD8_oRCvd1hfkIO2l6',
#      'width': 712}],
#    'place_id': 'ChIJ14y8u-i7QC4RJIFxbIfZWmQ',
#    'plus_code': {'compound_code': 'V8P3+9W Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P3+9W'},
#    'reference': 'ChIJ14y8u-i7QC4RJIFxbIfZWmQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Jalan Jendral Sudirman, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.114224999999998, 'lng': 105.3043537},
#     'viewport': {'northeast': {'lat': -5.112871819708499,
#       'lng': 105.3057026802915},
#      'southwest': {'lat': -5.115569780291502, 'lng': 105.3030047197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'KOPDARAN VLC CHAPTER METRO',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108548371453260223150">Ahmad Sobari</a>'],
#      'photo_reference': 'Aap_uEBpShJ28oSfqAUU8ztIvR12gcqkLMVO3VKVVmLOdLKZbmc9t6gMYS0XcASQxMcTDMkFGkNWAzPqudjHTC3bfmVaC6Ezd2erscBaR9zpeo5diHwMvCm5QiddMdvrYw0lhzPh-bHdUAmT4eZOaKIQejr027lnkWDfFTa-JkL4q3swbBg3',
#      'width': 3264}],
#    'place_id': 'ChIJsSXmhCi7QC4RJGQRT1fYhag',
#    'plus_code': {'compound_code': 'V8P3+8P Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P3+8P'},
#    'reference': 'ChIJsSXmhCi7QC4RJGQRT1fYhag',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Jalan Jendral Sudirman, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1125392, 'lng': 105.3096249},
#     'viewport': {'northeast': {'lat': -5.111239769708497,
#       'lng': 105.3110080802915},
#      'southwest': {'lat': -5.113937730291502, 'lng': 105.3083101197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Nuwo Sosro Kos Putri',
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113301593290355126017">Kaswan Sanusi</a>'],
#      'photo_reference': 'Aap_uECIYdd74yn7OrG2dc22Ydhh-gkEpbFuFHJZNbEr-KKEb2TixkerGrK3ZeYNoSaTLxLxx57FTBxsS6wU7E-1VQZ1slqlrKOrnEpJyvam5SA8oJtCnhpk-t4KLh9rxx1HjDFU92NMxElzh3AojzkrMDp2XC6QMIsrdElB3DJCQIex0JdO',
#      'width': 1600}],
#    'place_id': 'ChIJyfJO6cu7QC4RyzsdiZuTHRM',
#    'plus_code': {'compound_code': 'V8P5+XR Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P5+XR'},
#    'rating': 4.9,
#    'reference': 'ChIJyfJO6cu7QC4RyzsdiZuTHRM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 55,
#    'vicinity': 'Jalan Sosro Sudarmo No.15, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1101281, 'lng': 105.3062807},
#     'viewport': {'northeast': {'lat': -5.108779319708497,
#       'lng': 105.3076118802915},
#      'southwest': {'lat': -5.111477280291502, 'lng': 105.3049139197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'andi rifqi',
#    'photos': [{'height': 1772,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107425889428465403873">andi rifqi</a>'],
#      'photo_reference': 'Aap_uEAWIjTBjqh40gju-bUH3KjmkRfC37JyMjZChePDrzO2Ibi2rEgB8xvR-4TuY_LKaSpKvonqVGmnt10yCK1CVZlc1x8yEydlNKymQSbVK2W2UR2vAVoNtLYACJ1LGntazRJM2GEy8jg14zgOKTp2iWNYUl1qPpaWNzemm8BqsmdvwH00',
#      'width': 2953}],
#    'place_id': 'ChIJaT0S7ca7QC4ROWN5QhheErk',
#    'plus_code': {'compound_code': 'V8Q4+WG Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8Q4+WG'},
#    'rating': 1,
#    'reference': 'ChIJaT0S7ca7QC4ROWN5QhheErk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Jalan Bandar Marga, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.116160199999999, 'lng': 105.3080267},
#     'viewport': {'northeast': {'lat': -5.114905069708497,
#       'lng': 105.3093738802915},
#      'southwest': {'lat': -5.117603030291502, 'lng': 105.3066759197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Wisma Metro',
#    'photos': [{'height': 3264,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112241852610588661944">fenti pr</a>'],
#      'photo_reference': 'Aap_uEDOHqMVtY0H6Ej0iuI7OVttpLHKgY5H98wg-jtmeYcYbhkZIw5xrP5wi2IUKUt4P_shghbyPlOHrOODpshih5afSk9r42ABkJ5lnQJKXSDSWBEg_xmj3UHwbiK3NIJXMtgHecFAOwetwgRf76OcYzeC6lyFAVar8yPCKJzQAc9f9W3I',
#      'width': 2448}],
#    'place_id': 'ChIJbRNnb_m7QC4R94PjqxC1x7A',
#    'plus_code': {'compound_code': 'V8M5+G6 Metro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8M5+G6'},
#    'rating': 4.3,
#    'reference': 'ChIJbRNnb_m7QC4R94PjqxC1x7A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Jalan Brigjend Sutiyoso No.17, Metro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.1111667, 'lng': 105.3094444},
#     'viewport': {'northeast': {'lat': -5.109847919708497,
#       'lng': 105.3107922802915},
#      'southwest': {'lat': -5.112545880291502, 'lng': 105.3080943197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'mess metro',
#    'place_id': 'ChIJ5VQgzyS7QC4RJAD5YwaT-IU',
#    'plus_code': {'compound_code': 'V8Q5+GQ Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8Q5+GQ'},
#    'reference': 'ChIJ5VQgzyS7QC4RJAD5YwaT-IU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Jalan Raden Intan No.59, Imopuro'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -5.113748900000001, 'lng': 105.3033512},
#     'viewport': {'northeast': {'lat': -5.112223469708499,
#       'lng': 105.3047045802915},
#      'southwest': {'lat': -5.114921430291504, 'lng': 105.3020066197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Metro Pacifik',
#    'place_id': 'ChIJp48Ukfq7QC4RmnBSFWYQ7Z8',
#    'plus_code': {'compound_code': 'V8P3+G8 Imopuro, Metro City, Lampung, Indonesia',
#     'global_code': '6P67V8P3+G8'},
#    'rating': 3.5,
#    'reference': 'ChIJp48Ukfq7QC4RmnBSFWYQ7Z8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Jalan Ahmad Yani No.203, Imopuro'}],
#  'status': 'OK'}

# %%
hotel_df
# Out:
#          City Country  Max Temp      Lat       Lng  \
# 1    Acapulco      MX     78.62  16.8634  -99.8901
# 6       Vaini      TO     82.56 -21.2000 -175.2000
# 11     Mocuba      MZ     74.84 -16.8392   36.9856
# 14      Ilula      TZ     72.14  -7.6766   36.0366
# 17       Hilo      US     71.28  19.7297 -155.0900
# ..        ...     ...       ...      ...       ...
# 556  Impfondo      CG     75.61   1.6381   18.0667
# 557    Kupang      ID     88.38 -10.1667  123.5833
# 563    Yambio      SS     80.08   4.5721   28.3955
# 567    Marzuq      YE     72.45  14.4000   46.4667
# 568     Metro      ID     85.03  -5.1131  105.3067
#
#                          Hotel Name
# 1         HS Hotsson Smart Acapulco
# 6               Keleti Beach Resort
# 11                      Phama Lodge
# 14                         FM Lodge
# 17              Hilo Hawaiian Hotel
# ..                              ...
# 556       Auberge La Place de Jules
# 557  Hotel On The Rock by Prasanthi
# 563                  Naivasha Hotel
# 567
# 568          OYO 3177 Wisma Lintang
#
# [203 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
